# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import sys
sys.path.append('/content/gdrive/My Drive/densenet-pytorch-master_shift2')

# %%
# !python gdrive/My\ Drive/densenet-pytorch-master_shift2/train.py
# Out:
# Streaming output truncated to the last 5000 lines.
# Test: [110/157]	Time 0.027 (0.029)	Loss 0.2315 (0.2688)	Prec@1 90.625 (92.694)
# Test: [120/157]	Time 0.027 (0.029)	Loss 0.1205 (0.2658)	Prec@1 96.875 (92.756)
# Test: [130/157]	Time 0.026 (0.030)	Loss 0.5316 (0.2698)	Prec@1 89.062 (92.629)
# Test: [140/157]	Time 0.030 (0.029)	Loss 0.2906 (0.2657)	Prec@1 90.625 (92.697)
# Test: [150/157]	Time 0.031 (0.029)	Loss 0.1240 (0.2668)	Prec@1 96.875 (92.715)
#  * Prec@1 92.640
# Epoch: [248][0/782]	Time 0.169 (0.169)	Loss 0.0010 (0.0010)	Prec@1 100.000 (100.000)
# Epoch: [248][10/782]	Time 0.097 (0.104)	Loss 0.0010 (0.0013)	Prec@1 100.000 (100.000)
# Epoch: [248][20/782]	Time 0.097 (0.101)	Loss 0.0011 (0.0012)	Prec@1 100.000 (100.000)
# Epoch: [248][30/782]	Time 0.097 (0.100)	Loss 0.0022 (0.0011)	Prec@1 100.000 (100.000)
# Epoch: [248][40/782]	Time 0.097 (0.100)	Loss 0.0018 (0.0011)	Prec@1 100.000 (100.000)
# ...
